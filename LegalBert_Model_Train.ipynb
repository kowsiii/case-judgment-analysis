# %% [markdown]
# # NOTE TO FUTURE USERS
#
# Please only run the first one (aka, the one that links to legal_bert_model) since the rest have even worse performances somehows

# %%
#!unzip jsonl_files.zip

# %%
# model attempt 1
import os
import json
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForTokenClassification, TrainingArguments, Trainer
from transformers import DataCollatorForTokenClassification

folder_path = os.path.join("content/jsonl_files")
#tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
# |      >>> model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")
## |      >>> assistant_model = AutoModelForCausalLM.from_pretrained("distilbert/distilgpt2")
# |      >>> # set pad_token_id to eos_token_id because GPT2 does not have a PAD token
# |      >>> model.generation_config.pad_token_id = model.generation_config.eos_token_id
# |      >>> input_prompt = "It might be possible to"
# |      >>> input_ids = tokenizer(input_prompt, return_tensors="pt").input_ids
# |      >>> # instantiate logits processors
# |      >>> logits_processor = LogitsProcessorList(
# |      ...     [
# |      ...         MinLengthLogitsProcessor(10, eos_token_id=model.generation_config.eos_token_id),
# |      ...     ]
# |      ... )
# |      >>> stopping_criteria = StoppingCriteriaList([MaxLengthCriteria(max_length=20)])
# |      >>> outputs = model.assisted_decoding(
 #|      ...     input_ids,
 #|      ...     assistant_model=assistant_model,
 #|      ...     logits_processor=logits_processor,
 #|      ...     stopping_criteria=stopping_criteria,




# Define the label list based on your data
label_list = ["PRECEDENT", "LAWYER", "JUDGE", "RESPONDENT", "GPE",
              "DATE", "OTHER_PERSON", "PROVISION", "ORG", "PETITIONER",
              "WITNESS", "COURT", "STATUTE", "CASE_NUMBER"]


class CustomDataset(Dataset):
    def __init__(self, folder_path, tokenizer, label_list, max_length=512, split_ratio=0.8, seed=42):
        self.tokenizer = tokenizer
        self.label_list = label_list
        self.label_map = {label: i for i, label in enumerate(label_list)}
        self.samples = []
        self.max_length = max_length
        self.split_ratio = split_ratio
        self.seed = seed

        self._load_data(folder_path)
        self._split_data()

    def _load_data(self, folder_path):
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.jsonl'):
                file_path = os.path.join(folder_path, file_name)
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        text = data['text']
                        labels = data['label']
                        tokenized_inputs = self.tokenizer(
                            text,
                            is_split_into_words=True,
                            padding='max_length',
                            truncation=True,
                            max_length=self.max_length,
                            return_tensors='pt'
                        )
                        labels = self.align_labels(labels, tokenized_inputs.input_ids)
                        self.samples.append({
                            'input_ids': tokenized_inputs.input_ids,
                            'attention_mask': tokenized_inputs.attention_mask,
                            'labels': labels
                        })

    def _split_data(self):
        split_index = int(len(self.samples) * self.split_ratio)
        self.train_samples = self.samples[:split_index]
        self.eval_samples = self.samples[split_index:]

    def align_labels(self, labels, input_ids):
        aligned_labels = []
        label_idx = 0
        for i in range(input_ids.size(1)):
            token = self.tokenizer.convert_ids_to_tokens(input_ids[0, i].item())
            if token.startswith("##"):
                aligned_labels.append(-100)
            else:
                if label_idx < len(labels) and i >= labels[label_idx][0] and i <= labels[label_idx][1]:
                    aligned_labels.append(self.label_map.get(labels[label_idx][2], -100))
                else:
                    aligned_labels.append(-100)
                if label_idx < len(labels) and i == labels[label_idx][1]:
                    label_idx += 1
        return torch.tensor(aligned_labels)

    def __len__(self):
        return len(self.train_samples)

    def __getitem__(self, idx):
        sample = self.train_samples[idx]
        return sample

    def get_eval_dataset(self):
        return self.eval_samples


class CustomDataCollatorForTokenClassification(DataCollatorForTokenClassification):
    def __call__(self, features):
        batch = {}
        batch["input_ids"] = torch.stack([feature["input_ids"].squeeze() for feature in features])
        batch["attention_mask"] = torch.stack([feature["attention_mask"].squeeze() for feature in features])
        batch["labels"] = torch.stack([feature["labels"].squeeze() for feature in features])

        return batch

tokenizer = BertTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = BertForTokenClassification.from_pretrained("nlpaueb/legal-bert-base-uncased", num_labels=len(label_list))

data_collator = CustomDataCollatorForTokenClassification(tokenizer)
# Initialize dataset
dataset = CustomDataset(folder_path, tokenizer, label_list)

# Get evaluation dataset
eval_dataset = dataset.get_eval_dataset()

# Prepare training arguments and trainer
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    logging_dir='./logs',
)

# Initialize trainer after defining the model and label_list
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()

# Save the model
model.save_pretrained('./legal_bert_ner_model')
tokenizer.save_pretrained('./legal_bert_ner_model')
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at nlpaueb/legal-bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 00:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ('./legal_bert_ner_model/tokenizer_config.json',
#  './legal_bert_ner_model/special_tokens_map.json',
#  './legal_bert_ner_model/vocab.txt',
#  './legal_bert_ner_model/added_tokens.json')

# %%
# evaluation
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

# Get the predicted labels
predictions = trainer.predict(eval_dataset)

# Extract predicted label IDs
predicted_label_ids = np.argmax(predictions.predictions, axis=2)

# Flatten the predictions and labels to calculate accuracy and F1 score
flat_predictions = np.concatenate(predicted_label_ids)
flat_labels = np.concatenate([eval_dataset[i]["labels"].numpy() for i in range(len(eval_dataset))])

# Calculate accuracy
accuracy = accuracy_score(flat_labels, flat_predictions)

# Calculate precision, recall, F1 score
precision, recall, f1, _ = precision_recall_fscore_support(flat_labels, flat_predictions, average='micro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.08447265625
# Precision: 0.08447265625
# Recall: 0.08447265625
# F1 Score: 0.08447265625

# %%
import torch

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Put the model on the device
model.to(device)

# Set the model in evaluation mode
model.eval()

# Iterate over the evaluation dataset and make predictions
predictions = []
for batch in eval_dataset:
    # Move inputs to the appropriate device
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)

    # Disable gradient calculation
    with torch.no_grad():
        # Forward pass, get logits
        outputs = model(input_ids, attention_mask=attention_mask)

    # Get the predicted labels
    predicted_labels = torch.argmax(outputs.logits, dim=-1)
    
    # Append predictions to the list
    predictions.append(predicted_labels.detach().cpu().numpy())

# Convert the list of predictions to a single numpy array
predictions = np.concatenate(predictions)

# Now you have predictions for all samples in the evaluation dataset
print(predictions)

# Define a function to convert integer labels to label names
def convert_labels_to_names(predictions, label_list):
    label_names = []
    for pred in predictions:
        label_names.append([label_list[idx] for idx in pred])
    return label_names

# Convert predicted labels to label names
predicted_label_names = convert_labels_to_names(predictions, label_list)

# Print some examples of predicted labels
 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'PETITIONER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'PETITIONER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'LAWYER', 'RESPONDENT', 'PETITIONER', 'LAWYER', 'PETITIONER', 'COURT', 'LAWYER', 'PETITIONER', 'COURT', 'LAWYER', 'RESPONDENT', 'COURT', 'PETITIONER', 'LAWYER', 'LAWYER', 'LAWYER', 'PETITIONER', ' ...
# Predicted Labels: ['RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'PETITIONER', 'COURT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'PETITIONER', 'COURT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'PETITIONER', 'COURT', 'PETITIONER', 'PETITIONER', 'COURT', 'PETITIONER', 'COURT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'PETITIONER', 'PETITIONER', 'COURT', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'PETITIONER', 'PETITIONER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'PETITIONER', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'PETITIONER', 'PETITIONER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'PETITIONER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'COURT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'PETITIONER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'PETITIONER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'L ...
# Predicted Labels: ['RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'PETITIONER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'COURT', 'LAWYER', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'COURT', 'LAWYER', 'LAWYER', 'PETITIONER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'PETITIONER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'PETITIONER', 'LAWYER', 'RESPONDENT', 'PETITIONER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'PETITIONER', 'COURT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'PETITIONER', 'LAWYER', 'RESPONDENT', 'LAWYE ...

# %%
import os
import json
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForTokenClassification, DataCollatorForTokenClassification, TrainingArguments, Trainer
from sklearn.model_selection import train_test_split

folder_path = os.path.join("content/jsonl_files")

# Define the label list based on your data
label_list = ["PRECEDENT", "LAWYER", "JUDGE", "RESPONDENT", "GPE",
              "DATE", "OTHER_PERSON", "PROVISION", "ORG", "PETITIONER",
              "WITNESS", "COURT", "STATUTE", "CASE_NUMBER"]

# Split the data into train and validation sets
train_files, eval_files = train_test_split(os.listdir(folder_path), test_size=0.2, random_state=42)

class CustomDataset(Dataset):
    def __init__(self, file_list, tokenizer, label_list, max_length=512):
        self.tokenizer = tokenizer
        self.label_list = label_list
        self.label_map = {label: i for i, label in enumerate(label_list)}
        self.samples = []
        self.max_length = max_length

        self._load_data(file_list)

    def _load_data(self, file_list):
        for file_name in file_list:
            if file_name.endswith('.jsonl'):
                file_path = os.path.join(folder_path, file_name)
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        text = data['text']
                        labels = data['label']
                        tokenized_inputs = self.tokenizer(
                            text,
                            is_split_into_words=True,
                            padding='max_length',
                            truncation=True,
                            max_length=self.max_length,
                            return_tensors='pt'
                        )
                        labels = self.align_labels(labels, tokenized_inputs.input_ids)
                        self.samples.append({
                            'input_ids': tokenized_inputs.input_ids,
                            'attention_mask': tokenized_inputs.attention_mask,
                            'labels': labels
                        })

    def align_labels(self, labels, input_ids):
        aligned_labels = []
        label_idx = 0
        for i in range(input_ids.size(1)):
            token = self.tokenizer.convert_ids_to_tokens(input_ids[0, i].item())
            if token.startswith("##"):
                aligned_labels.append(-100)
            else:
                if label_idx < len(labels) and i >= labels[label_idx][0] and i <= labels[label_idx][1]:
                    aligned_labels.append(self.label_map.get(labels[label_idx][2], -100))
                else:
                    aligned_labels.append(-100)
                if label_idx < len(labels) and i == labels[label_idx][1]:
                    label_idx += 1
        return torch.tensor(aligned_labels)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]
        return sample

class CustomDataCollatorForTokenClassification(DataCollatorForTokenClassification):
    def __call__(self, features):
        batch = {}
        batch["input_ids"] = torch.stack([feature["input_ids"].squeeze() for feature in features])
        batch["attention_mask"] = torch.stack([feature["attention_mask"].squeeze() for feature in features])
        batch["labels"] = torch.stack([feature["labels"].squeeze() for feature in features])

        return batch

# Initialize tokenizer and model
tokenizer = BertTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = BertForTokenClassification.from_pretrained("nlpaueb/legal-bert-base-uncased", num_labels=len(label_list))

# Initialize train and validation datasets
train_dataset = CustomDataset(train_files, tokenizer, label_list)
eval_dataset = CustomDataset(eval_files, tokenizer, label_list)
data_collator = CustomDataCollatorForTokenClassification(tokenizer)
# Prepare training arguments and trainer
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    logging_dir='./logs',
)

# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()

# Save the model
model.save_pretrained('./legal_bert_ner_model2')
tokenizer.save_pretrained('./legal_bert_ner_model2')
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at nlpaueb/legal-bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 00:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ('./legal_bert_ner_model2/tokenizer_config.json',
#  './legal_bert_ner_model2/special_tokens_map.json',
#  './legal_bert_ner_model2/vocab.txt',
#  './legal_bert_ner_model2/added_tokens.json')

# %%
print(len(label_list))
# Out:
# 14

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import numpy as np

# Get the predicted labels
predictions = trainer.predict(eval_dataset)

# Extract predicted label IDs
predicted_label_ids = np.argmax(predictions.predictions, axis=2)

# Flatten the predictions and labels to calculate accuracy and F1 score
flat_predictions = np.concatenate(predicted_label_ids)
flat_labels = np.concatenate([eval_dataset[i]["labels"].numpy() for i in range(len(eval_dataset))])

# Calculate accuracy
accuracy = accuracy_score(flat_labels, flat_predictions)

# Calculate precision, recall, F1 score
precision, recall, f1, _ = precision_recall_fscore_support(flat_labels, flat_predictions, average='micro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.045654296875
# Precision: 0.045654296875
# Recall: 0.045654296875
# F1 Score: 0.045654296875

# %%
# Get the predicted labels
predictions = trainer.predict(eval_dataset)

# Extract predicted label IDs
predicted_label_ids = np.argmax(predictions.predictions, axis=2)

# Flatten the predictions and labels to calculate accuracy and F1 score
flat_predictions = np.concatenate(predicted_label_ids)
flat_labels = np.concatenate([eval_dataset[i]["labels"].numpy() for i in range(len(eval_dataset))])

# Calculate accuracy
accuracy = accuracy_score(flat_labels, flat_predictions)

# Calculate precision, recall, F1 score
precision, recall, f1, _ = precision_recall_fscore_support(flat_labels, flat_predictions, average='micro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.045654296875
# Precision: 0.045654296875
# Recall: 0.045654296875
# F1 Score: 0.045654296875

# %%
training_args = TrainingArguments(output_dir="test_trainer", use_mps_device=True)
# Out:
# /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/transformers/training_args.py:1983: UserWarning: `use_mps_device` is deprecated and will be removed in version 5.0 of 🤗 Transformers. `mps` device will be used by default if available similar to the way `cuda` device is used.Therefore, no action from user is required.
#   warnings.warn(

# %%
import torch

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Put the model on the device
model.to(device)

# Set the model in evaluation mode
model.eval()

# Iterate over the evaluation dataset and make predictions
predictions = []
for batch in eval_dataset:
    # Move inputs to the appropriate device
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)

    # Disable gradient calculation
    with torch.no_grad():
        # Forward pass, get logits
        outputs = model(input_ids, attention_mask=attention_mask)

    # Get the predicted labels
    predicted_labels = torch.argmax(outputs.logits, dim=-1)
    
    # Append predictions to the list
    predictions.append(predicted_labels.detach().cpu().numpy())

# Convert the list of predictions to a single numpy array
predictions = np.concatenate(predictions)

# Now you have predictions for all samples in the evaluation dataset
print(predictions)

# Define a function to convert integer labels to label names
def convert_labels_to_names(predictions, label_list):
    label_names = []
    for pred in predictions:
        label_names.append([label_list[idx] for idx in pred])
    return label_names

# Convert predicted labels to label names
predicted_label_names = convert_labels_to_names(predictions, label_list)

# Print some examples of predicted labels
for i in range(5):  # Print the first 5 examples
    print("Predicted Labels:", predicted_label_names[i])

u_pred = []
for doc in predicted_label_names:
    for pred in doc:
        if pred not in u_pred:
            u_pred.append(pred)

print(u_pred)
# Out:
# [[11 11 11 ...  1  1  3]
#  [11 11 11 ... 11  3  3]
#  [11  0 11 ...  1  1  3]
#  ...
#  [11 11 11 ...  1  1  3]
#  [11 11 11 ...  3  3  3]
#  [11  0 11 ...  1  1  3]]
# Predicted Labels: ['COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'LAWYER', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'PETITIONER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'COURT', 'PETITIONER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'PETITIONER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 
', 'RESPONDENT', 'RESPONDENT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'PRECEDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'PETITIONER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYE ...
# Predicted Labels: ['COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'PETITIONER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'PETITIONER', 'PETITIONER', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'PETITIONER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', ...
# Predicted Labels: ['COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'COURT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'PETITIONER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'LAWYER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'LAWYER', 'COURT', 'COURT', 'LAWYER', 'LAWYER', 'COURT', 'COURT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'LAWYER', 'COURT', 'COURT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'COURT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'RESPONDENT', 'COURT', 'LAWYER', 'RESPONDENT', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'LAWYER', 'LAWYER', 'RESPONDENT', 'RESPONDENT', 'LAWYER', 'LAWYER', 'LAWYER', 'RESPONDENT', 'COURT', 'RESPONDENT', 'COURT', 'COURT', 'RESPONDENT', 'RESPONDENT', ' ...
# ['COURT', 'LAWYER', 'RESPONDENT', 'PETITIONER', 'PRECEDENT']

# %%
import json
import torch
from transformers import BertTokenizer, BertForTokenClassification

# Load the tokenizer and model
tokenizer = BertTokenizer.from_pretrained("legal_bert_ner_model2")

# Specify the directory containing the model.safetensors file
model_path = "legal_bert_ner_model2"

# Load the model
model = BertForTokenClassification.from_pretrained(model_path)

# Load new data from JSON Lines file
new_texts = []
with open("admin.jsonl", "r") as file:
    for line in file:
        # Load JSON object from each line
        json_obj = json.loads(line)
        # Extract text from JSON object (assuming "text" field)
        new_texts.append(json_obj["text"])

# Iterate through each new text
for text in new_texts:
    # Tokenize the text
    tokenized_inputs = tokenizer(text, is_split_into_words=True, padding='max_length', truncation=True, max_length=512, return_tensors='pt')

    # Model inference
    with torch.no_grad():
        outputs = model(**tokenized_inputs)

    # Get predicted labels
    predicted_labels = torch.argmax(outputs.logits, dim=-1)

    # Convert token IDs back to tokens and display along with labels
    tokens = tokenizer.convert_ids_to_tokens(tokenized_inputs.input_ids[0])
    for token, label_idx in zip(tokens, predicted_labels[0]):
        label_value = model.config.id2label[label_idx.item()]
        #print(label_idx)
        print(f"{token}: {label_list[len(label_value.split(_)[-1])]}")
# Out:
# [CLS]: PROVISION
# won: ORG
# ##g: ORG
# fo: PROVISION
# ##ong: ORG
# cha: ORG
# ##i: ORG
# v: PROVISION
# li: ORG
# ##n: ORG
# ku: ORG
# ##o: ORG
# ha: PROVISION
# ##o: ORG
# [: PROVISION
# 2005: PROVISION
# ]: ORG
# s: ORG
# ##gh: PROVISION
# ##c: ORG
# 77: PROVISION
# case: PROVISION
# number: PROVISION
# :: PROVISION
# boc: PROVISION
# 265: PROVISION
# /: PROVISION
# 2004: PROVISION
# ,: PROVISION
# sic: PROVISION
# 658: PROVISION
# ##0: PROVISION
# /: PROVISION
# 2004: PROVISION
# decision: PROVISION
# date: PROVISION
# :: PROVISION
# 26: PROVISION
# april: PROVISION
# 2005: ORG
# tribunal: PROVISION
# /: PROVISION
# court: PROVISION
# :: PROVISION
# high: PROVISION
# court: PROVISION
# cor: PROVISION
# ##am: PROVISION
# :: PROVISION
# andrew: PROVISION
# ph: PROVISION
# ##ang: ORG
# boon: PROVISION
# leon: PROVISION
# ##g: ORG
# j: PROVISION
# ##c: ORG
# counsel: PROVISION
# name: PROVISION
# (: PROVISION
# s: PROVISION
# ): PROVISION
# :: PROVISION
# gan: PROVISION
# ##es: PROVISION
# ##h: PROVISION
# s: PROVISION
# ram: PROVISION
# ##ana: PROVISION
# ##than: PROVISION
# and: PROVISION
# ren: ORG
# ##uka: ORG
# che: ORG
# ##tti: ORG
# ##ar: ORG
# (: PROVISION
# kar: PROVISION
# ##up: ORG
# ##pan: PROVISION
# che: ORG
# ##tti: ORG
# ##ar: ORG
# and: PROVISION
# partners: ORG
# ): PROVISION
# for: PROVISION
# the: ORG
# applicant: ORG
# ;: PROVISION
# chan: PROVISION
# wang: PROVISION
# ho: PROVISION
# (: PROVISION
# insolvency: ORG
# and: PROVISION
# public: ORG
# trustee: ORG
# ': PROVISION
# s: ORG
# office: ORG
# ): ORG
# for: PROVISION
# the: ORG
# public: ORG
# trustee: ORG
# parties: PROVISION
# :: PROVISION
# won: ORG
# ##g: ORG
# fo: PROVISION
# ##ong: ORG
# cha: ORG
# ##i: ORG
# -: PROVISION
# -: PROVISION
# li: PROVISION
# ##n: ORG
# ku: PROVISION
# ##o: ORG
# ha: PROVISION
# ##o: ORG
# civil: PROVISION
# procedure: PROVISION
# -: PROVISION
# rules: PROVISION
# of: PROVISION
# court: ORG
# -: PROVISION
# whether: PROVISION
# presumption: ORG
# under: PROVISION
# o: PROVISION
# 59: ORG
# r: ORG
# 28: ORG
# (: ORG
# 2: ORG
# ): ORG
# (: ORG
# b: ORG
# ): ORG
# rules: ORG
# of: ORG
# court: ORG
# conclusive: PROVISION
# -: ORG
# whether: PROVISION
# s: PROVISION
# 18: ORG
# (: ORG
# 3: PROVISION
# ): ORG
# motor: ORG
# vehicles: PROVISION
# (: PROVISION
# third: PROVISION
# -: PROVISION
# party: PROVISION
# risks: ORG
# and: PROVISION
# compensation: ORG
# ): PROVISION
# act: PROVISION
# operating: PROVISION
# as: ORG
# overriding: ORG
# statutory: PROVISION
# provision: ORG
# -: ORG
# section: PROVISION
# 4: PROVISION
# (: PROVISION
# 3: PROVISION
# ): ORG
# evidence: PROVISION
# act: PROVISION
# (: PROVISION
# cap: PROVISION
# 97: PROVISION
# ,: ORG
# 1997: PROVISION
# rev: ORG
# e: PROVISION
# ##d: PROVISION
# ): PROVISION
# ,: PROVISION
# s: PROVISION
# 18: ORG
# (: PROVISION
# 3: PROVISION
# ): ORG
# motor: PROVISION
# vehicles: PROVISION
# court: ORG
# of: ORG
# the: ORG
# republic: ORG
# of: ORG
# singa: ORG
# ##pore: ORG
# [: ORG
# 2017: ORG
# ]: ORG
# s: ORG
# ##gh: ORG
# ##c: ORG
# 252: ORG
# magistrate: ORG
# ': ORG
# s: ORG
# appeal: ORG
# no: ORG
# 911: ORG
# ##0: ORG
# of: ORG
# 2017: ORG
# between: ORG
# mi: ORG
# ##a: ORG
# muk: ORG
# ##les: ORG
# .: ORG
# .: ORG
# .: ORG
# appellant: ORG
# and: ORG
# public: ORG
# prosecutor: ORG
# .: ORG
# .: ORG
# .: ORG
# respondent: ORG
# judgment: ORG
# [: ORG
# criminal: ORG
# procedure: ORG
# and: ORG
# sentencing: ORG
# ]: ORG
# -: ORG
# -: ORG
# [: ORG
# appeal: ORG
# ]: ORG
# [: ORG
# criminal: ORG
# law: ORG
# ]: ORG
# -: ORG
# -: ORG
# [: ORG
# statutory: ORG
# offences: ORG
# ]: ORG
# -: ORG
# -: ORG
# [: ORG
# work: ORG
# injury: ORG
# compensation: ORG
# act: ORG
# (: ORG
# cap: ORG
# 354: ORG
# ,: ORG
# 2009: ORG
# rev: ORG
# e: PROVISION
# ##d: ORG
# ): ORG
# ]: ORG
# mi: ORG
# ##a: ORG
# muk: ORG
# ##les: ORG
# v: ORG
# public: ORG
# prosecutor: ORG
# [: ORG
# 2017: ORG
# ]: ORG
# s: ORG
# ##gh: ORG
# ##c: ORG
# 252: ORG
# high: ORG
# court: ORG
# -: ORG
# -: ORG
# magistrate: ORG
# ': ORG
# s: ORG
# appeal: ORG
# no: ORG
# 911: ORG
# ##0: ORG
# of: ORG
# 2017: ORG
# steven: ORG
# chong: ORG
# ja: ORG
# 31: ORG
# august: ORG
# 2017: ORG
# 13: ORG
# october: ORG
# 2017: ORG
# judgment: ORG
# reserved: ORG
# .: ORG
# steven: ORG
# chong: ORG
# ja: ORG
# :: ORG
# introduction: PROVISION
# 1: PROVISION
# the: PROVISION
# appellant: PROVISION
# ,: PROVISION
# mi: PROVISION
# ##a: PROVISION
# muk: PROVISION
# ##les: PROVISION
# ,: PROVISION
# is: PROVISION
# a: PROVISION
# bang: PROVISION
# ##lade: PROVISION
# ##s: ORG
# ##hi: ORG
# who: PROVISION
# worked: PROVISION
# for: PROVISION
# we: PROVISION
# ##e: PROVISION
# sen: PROVISION
# ##g: ORG
# marine: PROVISION
# and: PROVISION
# engineering: ORG
# p: ORG
# ##t: PROVISION
# ##e: PROVISION
# ltd: PROVISION
# (: PROVISION
# ": PROVISION
# we: PROVISION
# ##e: PROVISION
# sen: PROVISION
# ##g: PROVISION
# ": PROVISION
# ): PROVISION
# .: PROVISION
# at: PROVISION
# the: PROVISION
# material: PROVISION
# time: PROVISION
# ,: PROVISION
# he: PROVISION
# was: PROVISION
# working: PROVISION
# on: PROVISION
# a: PROVISION
# modular: PROVISION
# section: PROVISION
# of: PROVISION
# a: PROVISION
# hull: PROVISION
# under: PROVISION
# construction: PROVISION
# (: PROVISION
# ": PROVISION
# the: PROVISION
# block: PROVISION
# appellant: PROVISION
# ': PROVISION
# s: PROVISION
# evidence: PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# m: ORG
# +: ORG
# w: ORG
# singa: ORG
# ##pore: ORG
# p: ORG
# ##t: ORG
# ##e: ORG
# ltd: ORG
# v: ORG
# leo: ORG
# ##w: ORG
# te: ORG
# ##t: ORG
# s: ORG
# ##in: ORG
# and: ORG
# another: ORG
# [: PROVISION
# 2015: ORG
# ]: ORG
# s: ORG
# ##gh: PROVISION
# ##c: ORG
# 10: PROVISION
# case: PROVISION
# number: PROVISION
# :: PROVISION
# suit: PROVISION
# no: PROVISION
# 731: PROVISION
# of: PROVISION
# 2011: PROVISION
# decision: PROVISION
# date: PROVISION
# :: PROVISION
# 16: PROVISION
# january: PROVISION
# 2015: ORG
# tribunal: PROVISION
# /: PROVISION
# court: PROVISION
# :: PROVISION
# high: PROVISION
# court: PROVISION
# cor: PROVISION
# ##am: PROVISION
# :: PROVISION
# judit: ORG
# ##h: PROVISION
# pra: ORG
# ##kas: ORG
# ##h: ORG
# j: PROVISION
# counsel: PROVISION
# name: PROVISION
# (: PROVISION
# s: PROVISION
# ): PROVISION
# :: PROVISION
# chu: PROVISION
# ##a: PROVISION
# sui: PROVISION
# to: PROVISION
# ##ng: PROVISION
# ,: PROVISION
# lim: PROVISION
# wei: PROVISION
# lee: PROVISION
# ,: PROVISION
# daniel: PROVISION
# ta: PROVISION
# ##n: PROVISION
# ,: PROVISION
# huang: PROVISION
# ha: PROVISION
# ##ogen: PROVISION
# (: PROVISION
# won: PROVISION
# ##g: PROVISION
# ##partner: PROVISION
# ##ship: ORG
# llp: ORG
# ): PROVISION
# for: PROVISION
# the: ORG
# plaintiff: ORG
# ;: PROVISION
# nar: PROVISION
# ##aya: ORG
# ##n: PROVISION
# ##an: PROVISION
# vi: ORG
# ##ja: ORG
# ##y: PROVISION
# kum: ORG
# ##ar: ORG
# and: PROVISION
# n: PROVISION
# ##iro: ORG
# ##ze: PROVISION
# id: ORG
# ##ro: ORG
# ##o: ORG
# ##s: PROVISION
# (: PROVISION
# vi: ORG
# ##ja: ORG
# ##y: ORG
# &: PROVISION
# co: ORG
# ): ORG
# for: PROVISION
# the: ORG
# defendants: ORG
# .: ORG
# parties: ORG
# :: PROVISION
# m: ORG
# +: ORG
# w: ORG
# singa: ORG
# ##pore: ORG
# p: ORG
# ##t: ORG
# ##e: ORG
# ltd: ORG
# -: ORG
# -: ORG
# leo: ORG
# ##w: ORG
# te: ORG
# ##t: ORG
# s: ORG
# ##in: ORG
# and: ORG
# another: ORG
# 16: PROVISION
# january: PROVISION
# 2015: ORG
# judgment: ORG
# reserved: PROVISION
# .: ORG
# judit: ORG
# ##h: ORG
# pra: ORG
# ##kas: ORG
# ##h: ORG
# j: ORG
# :: PROVISION
# introduction: PROVISION
# 1: PROVISION
# the: PROVISION
# plaintiff: PROVISION
# ,: PROVISION
# m: PROVISION
# +: PROVISION
# w: ORG
# singa: PROVISION
# ##pore: ORG
# p: ORG
# ##t: ORG
# ##e: PROVISION
# ,: PROVISION
# jointly: PROVISION
# and: PROVISION
# severally: PROVISION
# ,: PROVISION
# on: PROVISION
# the: PROVISION
# basis: PROVISION
# that: PROVISION
# :: PROVISION
# (: PROVISION
# a: PROVISION
# ): PROVISION
# they: PROVISION
# dishonest: PROVISION
# ##ly: PROVISION
# assisted: PROVISION
# in: PROVISION
# a: PROVISION
# breach: PROVISION
# of: PROVISION
# trust: PROVISION
# ;: PROVISION
# or: PROVISION
# (: PROVISION
# b: PROVISION
# ): PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# the: PROVISION
# ": ORG
# titan: ORG
# unit: ORG
# ##y: ORG
# ": ORG
# [: PROVISION
# 2013: ORG
# ]: ORG
# s: ORG
# ##gh: PROVISION
# ##c: ORG
# ##r: PROVISION
# 28: PROVISION
# case: PROVISION
# number: PROVISION
# :: PROVISION
# admiralt: ORG
# ##y: ORG
# in: PROVISION
# rem: ORG
# no: PROVISION
# 276: PROVISION
# of: ORG
# 2012: ORG
# (: PROVISION
# summons: PROVISION
# no: ORG
# 402: ORG
# ##1: ORG
# and: PROVISION
# 449: PROVISION
# ##0: ORG
# of: ORG
# 2013: ORG
# ): PROVISION
# decision: PROVISION
# date: PROVISION
# :: PROVISION
# 19: PROVISION
# december: PROVISION
# 2013: ORG
# tribunal: PROVISION
# /: PROVISION
# court: PROVISION
# :: PROVISION
# high: PROVISION
# court: PROVISION
# cor: PROVISION
# ##am: PROVISION
# :: PROVISION
# sha: PROVISION
# ##un: ORG
# leon: PROVISION
# ##g: ORG
# li: ORG
# shi: ORG
# ##ong: ORG
# ar: PROVISION
# counsel: PROVISION
# name: PROVISION
# (: PROVISION
# s: PROVISION
# ): PROVISION
# :: PROVISION
# mr: ORG
# to: PROVISION
# ##h: PROVISION
# ki: PROVISION
# ##an: PROVISION
# s: ORG
# ##ing: ORG
# s: PROVISION
# ##c: ORG
# ,: PROVISION
# mr: ORG
# ti: PROVISION
# ##ng: ORG
# yong: PROVISION
# hong: PROVISION
# and: PROVISION
# mr: ORG
# nathan: PROVISION
# ##a: ORG
# ##e: PROVISION
# ##l: ORG
# li: PROVISION
# ##n: PROVISION
# (: PROVISION
# raja: PROVISION
# ##h: PROVISION
# &: PROVISION
# tann: PROVISION
# llp: PROVISION
# ): PROVISION
# for: PROVISION
# the: ORG
# plaintiff: ORG
# ;: PROVISION
# mr: ORG
# chan: PROVISION
# len: PROVISION
# ##g: PROVISION
# sun: PROVISION
# s: ORG
# ##c: ORG
# (: PROVISION
# baker: ORG
# &: ORG
# mcke: ORG
# ##nzie: ORG
# .: PROVISION
# won: ORG
# ##g: PROVISION
# &: PROVISION
# leo: ORG
# ##w: ORG
# ): PROVISION
# instructed: ORG
# by: ORG
# mr: ORG
# dennis: PROVISION
# ta: PROVISION
# ##n: PROVISION
# and: PROVISION
# mr: ORG
# edwi: ORG
# ##n: ORG
# ca: ORG
# ##i: ORG
# (: PROVISION
# dennis: PROVISION
# ##math: ORG
# ##i: ORG
# ##ew: PROVISION
# ): PROVISION
# for: PROVISION
# the: PROVISION
# first: ORG
# defendant: ORG
# ;: ORG
# mr: ORG
# thi: ORG
# ##o: ORG
# she: ORG
# ##n: PROVISION
# y: ORG
# ##i: ORG
# s: ORG
# ##c: PROVISION
# (: PROVISION
# t: ORG
# ##s: PROVISION
# ##mp: ORG
# law: PROVISION
# corporation: PROVISION
# ): PROVISION
# and: PROVISION
# mr: ORG
# kenneth: ORG
# ta: ORG
# ##n: ORG
# s: PROVISION
# ##c: PROVISION
# (: PROVISION
# kenneth: ORG
# ta: PROVISION
# ##n: PROVISION
# partnership: ORG
# ): ORG
# instructed: PROVISION
# by: ORG
# ms: PROVISION
# ta: ORG
# ##n: PROVISION
# mu: ORG
# ##i: PROVISION
# t: PROVISION
# ##ze: PROVISION
# (: PROVISION
# pan: PROVISION
# asia: PROVISION
# wi: PROVISION
# ##k: PROVISION
# ##borg: PROVISION
# rein: PROVISION
# llc: PROVISION
# ): PROVISION
# for: PROVISION
# the: PROVISION
# second: PROVISION
# defendant: PROVISION
# .: ORG
# parties: PROVISION
# :: PROVISION
# the: ORG
# ": ORG
# titan: PROVISION
# unit: ORG
# ##y: PROVISION
# ": PROVISION
# 19: PROVISION
# december: PROVISION
# 2013: PROVISION
# judgment: ORG
# reserved: PROVISION
# .: ORG
# sha: ORG
# ##un: ORG
# leon: PROVISION
# ##g: ORG
# li: PROVISION
# shi: ORG
# ##ong: ORG
# ar: PROVISION
# :: PROVISION
# introduction: PROVISION
# 1: PROVISION
# the: PROVISION
# central: PROVISION
# question: PROVISION
# raised: PROVISION
# in: PROVISION
# the: PROVISION
# present: PROVISION
# application: PROVISION
# concerns: PROVISION
# the: PROVISION
# threshold: PROVISION
# to: PROVISION
# be: PROVISION
# applied: PROVISION
# to: PROVISION
# determine: PROVISION
# the: PROVISION
# existence: PROVISION
# of: PROVISION
# an: PROVISION
# arbitration: PROVISION
# agreement: PROVISION
# in: PROVISION
# order: PROVISION
# to: PROVISION
# invoke: PROVISION
# the: PROVISION
# court: PROVISION
# ': PROVISION
# s: PROVISION
# jurisdiction: PROVISION
# to: PROVISION
# grant: PROVISION
# a: PROVISION
# stay: PROVISION
# in: PROVISION
# favour: PROVISION
# of: PROVISION
# arbitration: PROVISION
# pursuant: PROVISION
# to: PROVISION
# section: PROVISION
# 6: PROVISION
# of: PROVISION
# the: PROVISION
# international: ORG
# arbitration: PROVISION
# act: PROVISION
# (: PROVISION
# cap: PROVISION
# .: ORG
# 143: PROVISION
# ##a: PROVISION
# ,: PROVISION
# 2002: PROVISION
# rev: PROVISION
# e: PROVISION
# ##d: PROVISION
# ): PROVISION
# (: PROVISION
# ": PROVISION
# i: PROVISION
# ##a: PROVISION
# ##a: PROVISION
# ": PROVISION
# ): PROVISION
# .: PROVISION
# background: PROVISION
# 2: PROVISION
# the: PROVISION
# plaintiff: PROVISION
# ,: PROVISION
# a: PROVISION
# bank: PROVISION
# registered: PROVISION
# under: PROVISION
# the: PROVISION
# laws: PROVISION
# of: PROVISION
# germany: PROVISION
# ,: PROVISION
# provided: PROVISION
# of: PROVISION
# the: PROVISION
# cargo: PROVISION
# ,: PROVISION
# for: PROVISION
# the: PROVISION
# direct: PROVISION
# loss: PROVISION
# arising: PROVISION
# from: PROVISION
# the: PROVISION
# defendants: PROVISION
# having: PROVISION
# delivered: PROVISION
# the: PROVISION
# cargo: PROVISION
# to: PROVISION
# third: PROVISION
# parties: PROVISION
# on: PROVISION
# 27: PROVISION
# january: PROVISION
# 2012: PROVISION
# without: PROVISION
# presentation: PROVISION
# of: PROVISION
# the: PROVISION
# bill: PROVISION
# ##s: PROVISION
# of: PROVISION
# lad: PROVISION
# ##ing: PROVISION
# .: PROVISION
# 3: PROVISION
# the: PROVISION
# second: PROVISION
# defendant: PROVISION
# (: PROVISION
# ": PROVISION
# singa: PROVISION
# ##pore: PROVISION
# tankers: PROVISION
# ": PROVISION
# ): PROVISION
# is: PROVISION
# the: PROVISION
# registered: PROVISION
# owner: PROVISION
# of: PROVISION
# the: PROVISION
# vessel: PROVISION
# .: PROVISION
# the: PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# singa: ORG
# ##pore: ORG
# telecom: ORG
# ##mun: ORG
# ##ica: ORG
# ##tions: ORG
# ltd: ORG
# v: ORG
# star: ORG
# ##hu: ORG
# ##b: ORG
# cable: ORG
# vis: ORG
# ##ion: ORG
# ltd: ORG
# [: ORG
# 2006: ORG
# ]: ORG
# sgc: PROVISION
# ##a: ORG
# 5: PROVISION
# case: ORG
# number: PROVISION
# :: PROVISION
# ca: PROVISION
# 58: PROVISION
# /: PROVISION
# 2005: ORG
# decision: PROVISION
# date: PROVISION
# :: PROVISION
# 06: PROVISION
# february: ORG
# 2006: ORG
# tribunal: PROVISION
# /: PROVISION
# court: PROVISION
# :: PROVISION
# court: PROVISION
# of: ORG
# appeal: ORG
# cor: ORG
# ##am: PROVISION
# :: PROVISION
# be: PROVISION
# ##linda: ORG
# an: PROVISION
# ##g: ORG
# saw: PROVISION
# e: ORG
# ##an: ORG
# j: PROVISION
# ;: PROVISION
# chao: PROVISION
# hick: PROVISION
# ti: PROVISION
# ##n: PROVISION
# ja: PROVISION
# ;: PROVISION
# yong: PROVISION
# pu: ORG
# ##ng: ORG
# how: PROVISION
# c: ORG
# ##j: PROVISION
# counsel: PROVISION
# name: PROVISION
# (: PROVISION
# s: ORG
# ): ORG
# :: PROVISION
# ta: PROVISION
# ##n: PROVISION
# kok: PROVISION
# quan: ORG
# s: ORG
# ##c: ORG
# ,: PROVISION
# kan: ORG
# ##n: PROVISION
# ##an: PROVISION
# ram: ORG
# ##es: ORG
# ##h: ORG
# ,: ORG
# sea: PROVISION
# ##n: PROVISION
# ta: ORG
# ##n: PROVISION
# kim: PROVISION
# kang: ORG
# and: PROVISION
# lam: PROVISION
# s: ORG
# ##in: ORG
# ye: ORG
# ##e: ORG
# (: PROVISION
# ta: PROVISION
# ##n: PROVISION
# kok: PROVISION
# quan: ORG
# partnership: ORG
# ): ORG
# for: PROVISION
# the: ORG
# appellant: ORG
# ;: ORG
# philip: PROVISION
# je: PROVISION
# ##y: PROVISION
# ##are: ORG
# ##t: PROVISION
# ##nam: PROVISION
# s: ORG
# ##c: ORG
# ,: ORG
# low: PROVISION
# cha: ORG
# ##i: PROVISION
# chong: ORG
# and: PROVISION
# a: PROVISION
# ##j: ORG
# ##inde: ORG
# ##rpa: ORG
# ##l: ORG
# singh: ORG
# (: PROVISION
# rod: ORG
# ##y: PROVISION
# ##k: ORG
# and: PROVISION
# davidson: ORG
# ): ORG
# for: ORG
# the: ORG
# respondent: ORG
# parties: ORG
# :: ORG
# singa: ORG
# ##pore: ORG
# telecom: ORG
# ##mun: ORG
# ##ica: ORG
# ##tions: ORG
# ltd: ORG
# -: PROVISION
# -: ORG
# star: PROVISION
# ##hu: ORG
# ##b: ORG
# cable: ORG
# vis: ORG
# ##ion: ORG
# ltd: ORG
# contract: ORG
# -: ORG
# breach: ORG
# -: PROVISION
# lease: PROVISION
# of: PROVISION
# appellant: PROVISION
# ': PROVISION
# s: PROVISION
# facilities: ORG
# to: PROVISION
# respondent: PROVISION
# for: PROVISION
# cable: PROVISION
# television: PROVISION
# roll: PROVISION
# -: PROVISION
# out: PROVISION
# to: PROVISION
# high: PROVISION
# -: PROVISION
# rise: PROVISION
# residential: PROVISION
# properties: PROVISION
# -: PROVISION
# respondent: PROVISION
# tapp: PROVISION
# ##ing: PROVISION
# into: PROVISION
# leased: PROVISION
# facilities: PROVISION
# to: PROVISION
# transmit: PROVISION
# cable: PROVISION
# television: PROVISION
# signal: PROVISION
# ##s: PROVISION
# to: PROVISION
# other: PROVISION
# types: PROVISION
# of: PROVISION
# properties: PROVISION
# -: PROVISION
# whether: PROVISION
# respondent: PROVISION
# breaching: PROVISION
# lease: PROVISION
# agreement: PROVISION
# by: PROVISION
# such: PROVISION
# conduct: PROVISION
# contract: PROVISION
# -: PROVISION
# contractual: ORG
# terms: PROVISION
# -: PROVISION
# admissibility: PROVISION
# of: PROVISION
# evidence: PROVISION
# -: PROVISION
# whether: PROVISION
# common: PROVISION
# assumption: PROVISION
# ##s: PROVISION
# arrived: PROVISION
# at: PROVISION
# prior: PROVISION
# to: PROVISION
# execution: PROVISION
# of: PROVISION
# contract: PROVISION
# admissible: PROVISION
# as: PROVISION
# evidence: PROVISION
# of: PROVISION
# factual: PROVISION
# background: PROVISION
# to: PROVISION
# aid: PROVISION
# in: PROVISION
# interpretation: PROVISION
# of: PROVISION
# contract: PROVISION
# -: PROVISION
# whether: PROVISION
# any: PROVISION
# estoppel: PROVISION
# by: PROVISION
# convention: PROVISION
# arising: PROVISION
# from: PROVISION
# such: PROVISION
# common: PROVISION
# assumption: PROVISION
# ##s: PROVISION
# so: PROVISION
# as: PROVISION
# to: PROVISION
# bar: PROVISION
# appellant: PROVISION
# from: PROVISION
# challenging: PROVISION
# respondent: PROVISION
# ': PROVISION
# s: PROVISION
# tapp: PROVISION
# ##ing: PROVISION
# contract: PROVISION
# -: PROVISION
# contractual: PROVISION
# terms: PROVISION
# -: PROVISION
# exclusion: PROVISION
# clauses: PROVISION
# -: PROVISION
# clause: PROVISION
# ): PROVISION
# ,: PROVISION
# and: PROVISION
# the: PROVISION
# respondent: PROVISION
# ,: PROVISION
# star: PROVISION
# ##hu: PROVISION
# ##b: PROVISION
# cable: ORG
# vis: PROVISION
# ##ion: PROVISION
# ltd: PROVISION
# (: PROVISION
# ": PROVISION
# s: PROVISION
# ##c: PROVISION
# ##v: ORG
# ": PROVISION
# ): PROVISION
# .: PROVISION
# the: PROVISION
# hearing: PROVISION
# below: PROVISION
# was: PROVISION
# confined: PROVISION
# to: PROVISION
# liability: PROVISION
# only: PROVISION
# ,: PROVISION
# with: PROVISION
# assessment: PROVISION
# of: PROVISION
# damages: PROVISION
# ,: PROVISION
# if: PROVISION
# ordered: PROVISION
# ,: PROVISION
# to: PROVISION
# proceed: PROVISION
# separately: PROVISION
# .: PROVISION
# the: PROVISION
# trial: PROVISION
# judge: PROVISION
# found: PROVISION
# that: PROVISION
# s: PROVISION
# ##c: PROVISION
# ##v: PROVISION
# had: PROVISION
# breached: PROVISION
# the: PROVISION
# n: PROVISION
# ##la: PROVISION
# ,: PROVISION
# but: PROVISION
# held: PROVISION
# that: PROVISION
# s: PROVISION
# ##ing: PROVISION
# ##tel: PROVISION
# could: PROVISION
# not: PROVISION
# recover: PROVISION
# the: PROVISION
# damages: PROVISION
# pleaded: PROVISION
# due: PROVISION
# to: PROVISION
# an: PROVISION
# exemption: PROVISION
# clause: PROVISION
# (: PROVISION
# ": PROVISION
# art: PROVISION
# 8: PROVISION
# .: PROVISION
# 5: PROVISION
# (: PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# add: PROVISION
# v: ORG
# ade: PROVISION
# [: ORG
# 2014: ORG
# ]: ORG
# s: ORG
# ##gh: ORG
# ##c: ORG
# 80: ORG
# case: ORG
# number: PROVISION
# :: PROVISION
# divorce: PROVISION
# no: ORG
# 54: PROVISION
# of: ORG
# 2012: ORG
# (: PROVISION
# registrar: ORG
# ': ORG
# s: ORG
# appeal: ORG
# from: ORG
# the: ORG
# state: ORG
# courts: ORG
# no: ORG
# 3000: PROVISION
# ##7: ORG
# of: ORG
# 2013: ORG
# ): ORG
# decision: ORG
# date: PROVISION
# :: PROVISION
# 21: ORG
# april: ORG
# 2014: ORG
# tribunal: PROVISION
# /: PROVISION
# court: ORG
# :: PROVISION
# high: PROVISION
# court: ORG
# cor: PROVISION
# ##am: PROVISION
# :: PROVISION
# cho: ORG
# ##o: ORG
# han: ORG
# tec: ORG
# ##k: ORG
# j: ORG
# counsel: ORG
# name: PROVISION
# (: ORG
# s: ORG
# ): ORG
# :: PROVISION
# kama: PROVISION
# ##lar: PROVISION
# ##aja: PROVISION
# ##n: PROVISION
# mala: PROVISION
# ##iya: PROVISION
# ##ndi: PROVISION
# che: ORG
# ##tti: ORG
# ##ar: ORG
# (: PROVISION
# raja: PROVISION
# ##n: PROVISION
# che: ORG
# ##tti: ORG
# ##ar: ORG
# llc: PROVISION
# ): ORG
# for: PROVISION
# the: ORG
# appellant: ORG
# ;: PROVISION
# ta: PROVISION
# ##n: ORG
# ti: ORG
# ##ong: ORG
# ge: ORG
# ##e: ORG
# andrew: PROVISION
# (: PROVISION
# andrew: PROVISION
# ta: PROVISION
# ##n: PROVISION
# ti: ORG
# ##ong: ORG
# ge: ORG
# ##e: ORG
# &: PROVISION
# co: ORG
# ): ORG
# for: ORG
# the: ORG
# respondent: ORG
# .: ORG
# parties: PROVISION
# :: PROVISION
# add: PROVISION
# -: PROVISION
# -: ORG
# ade: PROVISION
# 21: PROVISION
# april: PROVISION
# 2014: ORG
# judgment: ORG
# reserved: ORG
# .: ORG
# cho: ORG
# ##o: ORG
# han: ORG
# tec: ORG
# ##k: ORG
# j: ORG
# :: PROVISION
# 1: PROVISION
# this: PROVISION
# is: PROVISION
# an: PROVISION
# appeal: ORG
# by: PROVISION
# the: PROVISION
# appellant: ORG
# /: ORG
# wife: ORG
# against: PROVISION
# the: PROVISION
# decision: ORG
# of: PROVISION
# the: PROVISION
# district: PROVISION
# judge: PROVISION
# on: PROVISION
# 27: PROVISION
# september: PROVISION
# 2013: PROVISION
# .: PROVISION
# the: PROVISION
# three: PROVISION
# issues: PROVISION
# on: PROVISION
# appeal: PROVISION
# are: PROVISION
# :: PROVISION
# (: ORG
# a: PROVISION
# ): PROVISION
# access: PROVISION
# of: PROVISION
# the: PROVISION
# respondent: PROVISION
# to: PROVISION
# child: PROVISION
# a: PROVISION
# ;: PROVISION
# (: PROVISION
# b: PROVISION
# ): PROVISION
# maintenance: PROVISION
# to: PROVISION
# the: PROVISION
# children: PROVISION
# ;: PROVISION
# and: PROVISION
# (: PROVISION
# c: PROVISION
# ): PROVISION
# division: PROVISION
# of: PROVISION
# the: PROVISION
# matrimon: PROVISION
# ##ial: PROVISION
# home: PROVISION
# (: PROVISION
# 5: PROVISION
# -: PROVISION
# room: PROVISION
# flat: PROVISION
# in: PROVISION
# hou: PROVISION
# ##gang: PROVISION
# central: PROVISION
# ): PROVISION
# .: PROVISION
# 2: PROVISION
# the: PROVISION
# appellant: PROVISION
# was: PROVISION
# born: PROVISION
# in: PROVISION
# august: PROVISION
# 1973: PROVISION
# ,: PROVISION
# and: PROVISION
# the: PROVISION
# respondent: PROVISION
# /: PROVISION
# husband: PROVISION
# in: PROVISION
# april: PROVISION
# 1961: PROVISION
# .: PROVISION
# they: PROVISION
# were: PROVISION
# married: PROVISION
# for: PROVISION
# about: PROVISION
# 15: PROVISION
# years: PROVISION
# ,: PROVISION
# from: PROVISION
# 7: PROVISION
# july: PROVISION
# 1997: PROVISION
# to: PROVISION
# the: PROVISION
# date: PROVISION
# of: PROVISION
# interim: PROVISION
# judgment: PROVISION
# ,: PROVISION
# 23: PROVISION
# july: PROVISION
# 2012: PROVISION
# .: PROVISION
# they: PROVISION
# had: PROVISION
# three: PROVISION
# children: PROVISION
# of: PROVISION
# the: PROVISION
# marriage: PROVISION
# ,: PROVISION
# of: PROVISION
# which: PROVISION
# the: PROVISION
# el: PROVISION
# ##des: PROVISION
# ##t: PROVISION
# is: PROVISION
# ": PROVISION
# child: PROVISION
# a: PROVISION
# ": PROVISION
# (: PROVISION
# c: PROVISION
# ): PROVISION
# the: PROVISION
# respondent: PROVISION
# be: PROVISION
# allowed: PROVISION
# access: PROVISION
# to: PROVISION
# child: PROVISION
# a: PROVISION
# every: PROVISION
# monday: PROVISION
# from: PROVISION
# 7: PROVISION
# ##p: PROVISION
# ##m: PROVISION
# to: PROVISION
# 9: PROVISION
# ##p: PROVISION
# ##m: PROVISION
# ,: PROVISION
# subject: PROVISION
# to: PROVISION
# her: PROVISION
# tu: PROVISION
# ##ition: PROVISION
# and: PROVISION
# school: PROVISION
# schedule: PROVISION
# ##s: PROVISION
# ;: PROVISION
# (: PROVISION
# d: PROVISION
# ): PROVISION
# the: PROVISION
# respondent: PROVISION
# ,: PROVISION
# within: PROVISION
# 6: PROVISION
# months: PROVISION
# of: PROVISION
# the: PROVISION
# date: PROVISION
# of: PROVISION
# extraction: PROVISION
# of: PROVISION
# the: PROVISION
# final: PROVISION
# judgment: PROVISION
# ,: PROVISION
# is: PROVISION
# to: PROVISION
# transfer: PROVISION
# all: PROVISION
# his: PROVISION
# rights: PROVISION
# ,: PROVISION
# title: PROVISION
# and: PROVISION
# interest: PROVISION
# in: PROVISION
# the: PROVISION
# matrimon: PROVISION
# ##ial: PROVISION
# home: PROVISION
# to: PROVISION
# the: PROVISION
# appellant: PROVISION
# ,: PROVISION
# upon: PROVISION
# the: PROVISION
# appellant: PROVISION
# paying: PROVISION
# a: PROVISION
# consideration: PROVISION
# equivalent: PROVISION
# to: PROVISION
# 25: PROVISION
# %: PROVISION
# of: PROVISION
# the: PROVISION
# net: PROVISION
# value: PROVISION
# of: PROVISION
# the: PROVISION
# matrimon: PROVISION
# ##ial: PROVISION
# home: PROVISION
# (: PROVISION
# and: PROVISION
# if: PROVISION
# not: PROVISION
# transferred: PROVISION
# within: PROVISION
# 6: PROVISION
# months: PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# in: ORG
# the: ORG
# general: ORG
# division: ORG
# of: ORG
# the: ORG
# high: ORG
# court: ORG
# of: ORG
# the: ORG
# republic: ORG
# of: ORG
# singa: ORG
# ##pore: ORG
# [: ORG
# 2023: ORG
# ]: ORG
# s: ORG
# ##gh: ORG
# ##c: ORG
# 106: ORG
# originat: ORG
# ##ing: ORG
# application: ORG
# no: ORG
# 156: ORG
# of: ORG
# 2023: ORG
# in: ORG
# the: ORG
# matter: ORG
# of: ORG
# section: ORG
# 216: ORG
# ##a: ORG
# of: ORG
# the: ORG
# companies: ORG
# act: ORG
# 1967: ORG
# between: ORG
# ta: ORG
# ##not: ORG
# ##o: ORG
# sau: ORG
# i: ORG
# ##an: ORG
# .: ORG
# .: ORG
# .: ORG
# applicant: ORG
# and: ORG
# usp: ORG
# group: ORG
# limited: ORG
# .: ORG
# .: ORG
# .: ORG
# respondent: ORG
# originat: ORG
# ##ing: ORG
# application: ORG
# no: ORG
# 218: ORG
# of: ORG
# 2023: ORG
# in: ORG
# the: ORG
# matter: ORG
# of: ORG
# section: ORG
# 176: ORG
# of: ORG
# the: ORG
# companies: ORG
# act: ORG
# 1967: ORG
# between: ORG
# usp: ORG
# group: ORG
# limited: ORG
# .: ORG
# .: ORG
# .: ORG
# claimant: ORG
# and: ORG
# (: ORG
# 1: ORG
# ): ORG
# hint: ORG
# ##erland: ORG
# energy: ORG
# p: ORG
# ##t: ORG
# ##e: ORG
# ltd: ORG
# (: ORG
# 2: ORG
# ): ORG
# harmonic: ORG
# brothers: ORG
# p: ORG
# ##t: ORG
# ##e: ORG
# ltd: ORG
# (: ORG
# 3: ORG
# ): ORG
# hi: ORG
# ##a: ORG
# y: ORG
# ##i: ORG
# he: ORG
# ##ng: ORG
# (: ORG
# 4: ORG
# ): ORG
# lim: ORG
# shi: ORG
# wei: ORG
# .: ORG
# .: ORG
# .: ORG
# defendants: ORG
# judgment: ORG
# [: ORG
# companies: ORG
# -: PROVISION
# -: PROVISION
# members: PROVISION
# -: PROVISION
# -: PROVISION
# meetings: PROVISION
# -: PROVISION
# -: PROVISION
# beneficial: ORG
# shareholders: PROVISION
# seeking: PROVISION
# to: PROVISION
# requisition: PROVISION
# an: PROVISION
# extraordinary: ORG
# general: PROVISION
# meeting: ORG
# -: PROVISION
# -: ORG
# whether: PROVISION
# estoppel: PROVISION
# or: PROVISION
# the: ORG
# extended: ORG
# doctrine: ORG
# of: ORG
# res: ORG
# judicata: PROVISION
# can: PROVISION
# override: PROVISION
# the: PROVISION
# requirement: PROVISION
# that: PROVISION
# only: PROVISION
# members: PROVISION
# can: PROVISION
# requisition: PROVISION
# an: PROVISION
# extraordinary: PROVISION
# general: PROVISION
# meeting: PROVISION
# -: PROVISION
# -: PROVISION
# section: ORG
# 176: ORG
# (: PROVISION
# 1: PROVISION
# ): ORG
# companies: ORG
# act: PROVISION
# 1967: PROVISION
# (: PROVISION
# 2020: PROVISION
# rev: ORG
# e: PROVISION
# ##d: PROVISION
# ): ORG
# ]: PROVISION
# [: ORG
# companies: PROVISION
# -: PROVISION
# -: PROVISION
# statutory: ORG
# derivative: ORG
# action: PROVISION
# -: PROVISION
# -: ORG
# bringing: PROVISION
# statutory: ORG
# derivative: ORG
# action: PROVISION
# for: PROVISION
# permanent: PROVISION
# injunction: PROVISION
# with: PROVISION
# no: PROVISION
# good: PROVISION
# legal: PROVISION
# basis: PROVISION
# and: PROVISION
# with: PROVISION
# no: PROVISION
# credible: PROVISION
# evidence: PROVISION
# -: PROVISION
# -: ORG
# whether: PROVISION
# proposed: PROVISION
# action: PROVISION
# was: PROVISION
# prima: PROVISION
# facie: PROVISION
# in: PROVISION
# interests: PROVISION
# of: PROVISION
# company: PROVISION
# -: PROVISION
# -: PROVISION
# section: ORG
# 216: PROVISION
# ##a: PROVISION
# (: PROVISION
# 3: PROVISION
# ): PROVISION
# (: PROVISION
# c: PROVISION
# ): ORG
# companies: ORG
# act: PROVISION
# 1967: PROVISION
# (: PROVISION
# 2020: PROVISION
# rev: PROVISION
# e: PROVISION
# ##d: PROVISION
# ): ORG
# ]: ORG
# [: ORG
# companies: ORG
# -: PROVISION
# -: PROVISION
# statutory: ORG
# derivative: ORG
# action: ORG
# -: ORG
# -: ORG
# bringing: ORG
# statutory: ORG
# derivative: ORG
# action: ORG
# ...
# adopted: PROVISION
# a: PROVISION
# slightly: PROVISION
# modified: PROVISION
# representation: PROVISION
# of: PROVISION
# the: PROVISION
# trademark: PROVISION
# (: PROVISION
# see: PROVISION
# annex: PROVISION
# b: PROVISION
# ): PROVISION
# in: PROVISION
# that: PROVISION
# the: PROVISION
# word: PROVISION
# o: PROVISION
# ##to: PROVISION
# is: PROVISION
# now: PROVISION
# in: PROVISION
# prominent: PROVISION
# ,: PROVISION
# plain: PROVISION
# white: PROVISION
# block: PROVISION
# text: PROVISION
# with: PROVISION
# horizontal: PROVISION
# stripe: PROVISION
# ##s: PROVISION
# on: PROVISION
# the: PROVISION
# lower: PROVISION
# half: PROVISION
# of: PROVISION
# the: PROVISION
# letters: PROVISION
# ,: PROVISION
# set: PROVISION
# in: PROVISION
# a: PROVISION
# green: PROVISION
# box: PROVISION
# .: PROVISION
# in: PROVISION
# addition: PROVISION
# ,: PROVISION
# there: PROVISION
# is: PROVISION
# the: PROVISION
# word: PROVISION
# ": PROVISION
# body: PROVISION
# ##care: PROVISION
# ": PROVISION
# ,: PROVISION
# also: PROVISION
# in: PROVISION
# plain: PROVISION
# white: PROVISION
# block: PROVISION
# text: PROVISION
# set: PROVISION
# out: PROVISION
# in: PROVISION
# smaller: PROVISION
# type: PROVISION
# than: PROVISION
# the: PROVISION
# word: PROVISION
# ": PROVISION
# o: PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# international: ORG
# factors: ORG
# leas: ORG
# ##ing: ORG
# p: ORG
# ##t: ORG
# ##e: ORG
# ltd: ORG
# v: PROVISION
# the: ORG
# personal: ORG
# representative: ORG
# of: ORG
# ta: ORG
# ##n: ORG
# hoc: ORG
# ##k: ORG
# ke: ORG
# ##e: ORG
# &: ORG
# others: PROVISION
# [: PROVISION
# 2002: PROVISION
# ]: PROVISION
# s: PROVISION
# ##gh: PROVISION
# ##c: PROVISION
# 270: PROVISION
# case: PROVISION
# number: PROVISION
# :: PROVISION
# suit: PROVISION
# no: PROVISION
# 144: PROVISION
# ##3: PROVISION
# of: PROVISION
# 2001: PROVISION
# ,: PROVISION
# ra: PROVISION
# no: PROVISION
# 107: PROVISION
# of: ORG
# 2002: ORG
# decision: PROVISION
# date: PROVISION
# :: PROVISION
# 18: PROVISION
# november: PROVISION
# 2002: PROVISION
# tribunal: PROVISION
# /: PROVISION
# court: PROVISION
# :: PROVISION
# high: PROVISION
# court: PROVISION
# cor: PROVISION
# ##am: PROVISION
# :: PROVISION
# wo: PROVISION
# ##o: PROVISION
# bih: PROVISION
# li: PROVISION
# j: PROVISION
# ##c: PROVISION
# counsel: PROVISION
# name: PROVISION
# (: PROVISION
# s: PROVISION
# ): PROVISION
# :: PROVISION
# sea: PROVISION
# ##n: PROVISION
# lim: PROVISION
# and: PROVISION
# ta: PROVISION
# ##n: PROVISION
# a: PROVISION
# ##i: PROVISION
# ##k: PROVISION
# how: PROVISION
# (: PROVISION
# hi: PROVISION
# ##n: PROVISION
# ta: PROVISION
# ##t: PROVISION
# &: PROVISION
# partners: PROVISION
# ): PROVISION
# for: PROVISION
# the: ORG
# plaintiff: ORG
# ;: PROVISION
# hr: PROVISION
# ##i: PROVISION
# kum: PROVISION
# ##ar: ORG
# and: PROVISION
# gary: PROVISION
# low: PROVISION
# (: PROVISION
# drew: PROVISION
# &: PROVISION
# napi: PROVISION
# ##er: ORG
# llc: PROVISION
# ): PROVISION
# for: PROVISION
# all: ORG
# the: ORG
# defendants: ORG
# parties: PROVISION
# :: PROVISION
# -: PROVISION
# -: PROVISION
# civil: ORG
# procedure: PROVISION
# -: PROVISION
# summary: ORG
# judgment: ORG
# -: PROVISION
# application: ORG
# for: PROVISION
# summary: ORG
# judgment: ORG
# -: ORG
# counterclaim: PROVISION
# by: ORG
# defendants: PROVISION
# -: ORG
# application: PROVISION
# for: PROVISION
# stay: PROVISION
# of: ORG
# execution: PROVISION
# -: PROVISION
# whether: PROVISION
# to: PROVISION
# grant: PROVISION
# stay: PROVISION
# of: PROVISION
# execution: PROVISION
# where: ORG
# counterclaim: PROVISION
# existing: PROVISION
# contract: PROVISION
# -: PROVISION
# contractual: ORG
# terms: PROVISION
# -: PROVISION
# use: PROVISION
# of: PROVISION
# excess: PROVISION
# payment: PROVISION
# by: PROVISION
# borrower: PROVISION
# towards: PROVISION
# reduc: PROVISION
# ##ing: PROVISION
# principal: PROVISION
# sum: PROVISION
# due: ORG
# judgment: PROVISION
# grounds: PROVISION
# of: ORG
# decision: PROVISION
# background: PROVISION
# 1: PROVISION
# .: PROVISION
# the: PROVISION
# plaintiff: PROVISION
# international: ORG
# factors: PROVISION
# leas: ORG
# ##ing: ORG
# p: ORG
# ##t: ORG
# ##e: ORG
# ltd: ORG
# (: PROVISION
# ': PROVISION
# if: PROVISION
# ##l: PROVISION
# ': PROVISION
# ): PROVISION
# claims: PROVISION
# against: PROVISION
# the: PROVISION
# first: PROVISION
# and: PROVISION
# second: PROVISION
# defendants: PROVISION
# ta: ORG
# ##n: PROVISION
# hoc: PROVISION
# ##k: ORG
# ke: PROVISION
# ##e: PROVISION
# (: PROVISION
# deceased: PROVISION
# ): PROVISION
# and: PROVISION
# t: PROVISION
# ##hk: ORG
# realt: PROVISION
# ##y: PROVISION
# p: ORG
# ##t: PROVISION
# ##e: PROVISION
# ltd: PROVISION
# (: PROVISION
# ': PROVISION
# t: PROVISION
# ##hk: ORG
# realt: ORG
# ##y: PROVISION
# ': PROVISION
# ): PROVISION
# payment: PROVISION
# of: PROVISION
# an: PROVISION
# outstanding: PROVISION
# loan: PROVISION
# and: PROVISION
# interest: PROVISION
# .: PROVISION
# the: PROVISION
# third: PROVISION
# to: PROVISION
# fifth: PROVISION
# defendants: PROVISION
# ,: PROVISION
# i: PROVISION
# .: PROVISION
# e: PROVISION
# ta: PROVISION
# ##n: PROVISION
# hoc: PROVISION
# ##k: PROVISION
# ken: PROVISION
# ##g: PROVISION
# ,: PROVISION
# t: PROVISION
# ##h: PROVISION
# ##ng: PROVISION
# by: PROVISION
# an: PROVISION
# affidavit: PROVISION
# that: PROVISION
# provides: PROVISION
# a: PROVISION
# quantification: PROVISION
# of: PROVISION
# the: PROVISION
# defendants: PROVISION
# ': PROVISION
# counterclaim: PROVISION
# (: PROVISION
# iv: PROVISION
# ): PROVISION
# cost: PROVISION
# of: PROVISION
# the: PROVISION
# interlocutor: PROVISION
# ##y: PROVISION
# judgment: PROVISION
# shall: PROVISION
# be: PROVISION
# paid: PROVISION
# by: PROVISION
# the: PROVISION
# defendants: PROVISION
# to: PROVISION
# if: PROVISION
# ##l: PROVISION
# such: PROVISION
# cost: PROVISION
# to: PROVISION
# be: PROVISION
# reserved: PROVISION
# to: PROVISION
# the: PROVISION
# registrar: PROVISION
# assessing: PROVISION
# the: PROVISION
# quantum: PROVISION
# of: PROVISION
# the: PROVISION
# principal: PROVISION
# and: PROVISION
# interests: PROVISION
# due: PROVISION
# to: PROVISION
# if: PROVISION
# ##l: PROVISION
# (: PROVISION
# v: PROVISION
# ): PROVISION
# cost: PROVISION
# of: PROVISION
# the: PROVISION
# balance: PROVISION
# claim: PROVISION
# shall: PROVISION
# be: PROVISION
# cost: PROVISION
# in: PROVISION
# the: PROVISION
# cause: PROVISION
# .: PROVISION
# 3: PROVISION
# .: PROVISION
# at: PROVISION
# the: PROVISION
# hearing: PROVISION
# before: PROVISION
# the: PROVISION
# assistant: PROVISION
# registrar: PROVISION
# ,: PROVISION
# two: PROVISION
# main: PROVISION
# contention: PROVISION
# ##s: PROVISION
# were: PROVISION
# raised: PROVISION
# by: PROVISION
# the: PROVISION
# defendants: PROVISION
# .: PROVISION
# firstly: PROVISION
# ,: PROVISION
# the: PROVISION
# defendants: PROVISION
# argued: PROVISION
# that: PROVISION
# if: PROVISION
# ##l: PROVISION
# had: PROVISION
# claimed: PROVISION
# default: PROVISION
# interest: PROVISION
# at: PROVISION
# 18: PROVISION
# %: PROVISION
# per: PROVISION
# an: PROVISION
# ##n: PROVISION
# ##um: PROVISION
# against: PROVISION
# the: PROVISION
# defendants: PROVISION
# [SEP]: PROVISION
# [CLS]: ORG
# in: ORG
# the: ORG
# high: ORG
# court: ORG
# of: ORG
# the: ORG
# republic: ORG
# of: ORG
# singa: ORG
# ##pore: ORG
# [: ORG
# 2016: ORG
# ]: ORG
# s: ORG
# ##gh: ORG
# ##c: ORG
# 279: ORG
# originat: ORG
# ##ing: ORG
# summons: ORG
# no: ORG
# 153: ORG
# of: ORG
# 2016: ORG
# in: ORG
# the: ORG
# matter: ORG
# of: ORG
# section: ORG
# 210: ORG
# of: ORG
# the: ORG
# companies: ORG
# act: ORG
# (: ORG
# cap: ORG
# 50: ORG
# ): ORG
# and: ORG
# in: ORG
# the: ORG
# matter: ORG
# of: ORG
# conc: ORG
# ##hu: ORG
# ##bar: ORG
# aromat: ORG
# ##ic: ORG
# ##s: ORG
# ltd: ORG
# conc: ORG
# ##hu: ORG
# ##bar: ORG
# aromat: ORG
# ##ic: ORG
# ##s: ORG
# ltd: ORG
# .: ORG
# .: ORG
# .: ORG
# applicant: ORG
# originat: ORG
# ##ing: ORG
# summons: ORG
# no: ORG
# 154: ORG
# of: ORG
# 2016: ORG
# in: ORG
# the: ORG
# matter: ORG
# of: ORG
# section: ORG
# 210: ORG
# of: ORG
# the: ORG
# companies: ORG
# act: ORG
# (: ORG
# cap: ORG
# 50: ORG
# ): ORG
# and: ORG
# in: ORG
# the: ORG
# matter: ORG
# of: ORG
# u: ORG
# ##v: ORG
# ##m: ORG
# investment: ORG
# corporation: ORG
# u: ORG
# ##v: ORG
# ##m: ORG
# investment: ORG
# corporation: ORG
# .: ORG
# .: ORG
# .: ORG
# applicant: ORG
# grounds: ORG
# of: ORG
# decision: ORG
# [: ORG
# companies: ORG
# ]: ORG
# -: ORG
# -: ORG
# [: ORG
# schemes: ORG
# of: ORG
# arrangement: ORG
# ]: ORG
# re: ORG
# conc: ORG
# ##hu: ORG
# ##bar: ORG
# aromat: ORG
# ##ic: ORG
# ##s: ORG
# ltd: ORG
# and: ORG
# another: ORG
# matter: ORG
# [: ORG
# 2016: ORG
# ]: ORG
# s: ORG
# ##gh: ORG
# ##c: ORG
# 279: ORG
# high: ORG
# court: ORG
# -: ORG
# -: ORG
# originat: ORG
# ##ing: ORG
# summons: ORG
# no: ORG
# ##s: ORG
# 153: ORG
# and: ORG
# 154: ORG
# of: ORG
# 2016: ORG
# a: ORG
# ##ed: ORG
# ##it: ORG
# abdullah: ORG
# j: ORG
# ##c: ORG
# 29: ORG
# august: ORG
# ;: ORG
# 6: ORG
# october: ORG
# 2016: ORG
# 20: ORG
# december: ORG
# 2016: ORG
# a: ORG
# ##ed: ORG
# ##it: ORG
# abdullah: ORG
# j: ORG
# ##c: ORG
# :: ORG
# introduction: ORG
# 1: PROVISION
# by: PROVISION
# way: PROVISION
# of: ORG
# originat: ORG
# ##ing: ORG
# summons: ORG
# no: ORG
# 153: ORG
# and: ORG
# 154: ORG
# of: ORG
# 2016: PROVISION
# ,: PROVISION
# conc: PROVISION
# ##hu: ORG
# ##bar: ORG
# aromat: PROVISION
# ##ic: PROVISION
# ##s: ORG
# ltd: ORG
# and: PROVISION
# u: PROVISION
# ##v: PROVISION
# ##m: ORG
# investment: PROVISION
# corporation: ORG
# (: PROVISION
# ": PROVISION
# conc: PROVISION
# ##hu: ORG
# ##bar: PROVISION
# ": PROVISION
# and: PROVISION
# ": PROVISION
# u: PROVISION
# ##v: ORG
# ##m: ORG
# ": PROVISION
# respectively: PROVISION
# and: PROVISION
# ": PROVISION
# the: PROVISION
# applicants: ORG
# ": PROVISION
# collectively: PROVISION
# ): PROVISION
# sought: PROVISION
# the: PROVISION
# court: ORG
# ': PROVISION
# s: PROVISION
# leave: PROVISION
# for: PROVISION
# them: PROVISION
# to: PROVISION
# each: PROVISION
# convene: PROVISION
# a: PROVISION
# meeting: PROVISION
# of: PROVISION
# their: PROVISION
# respective: ORG
# creditors: PROVISION
# for: PROVISION
# the: PROVISION
# purpose: PROVISION
# of: PROVISION
# considering: PROVISION
# and: PROVISION
# approving: PROVISION
# a: PROVISION
# proposed: PROVISION
# ##ic: PROVISION
# ##s: PROVISION
# corporation: PROVISION
# p: PROVISION
# ##t: PROVISION
# ##e: PROVISION
# ltd: PROVISION
# (: PROVISION
# ": PROVISION
# jac: PROVISION
# ": PROVISION
# ): PROVISION
# which: PROVISION
# it: PROVISION
# owned: PROVISION
# indirectly: PROVISION
# ;: PROVISION
# conc: PROVISION
# ##hu: PROVISION
# ##bar: PROVISION
# held: PROVISION
# 26: PROVISION
# .: PROVISION
# 7: PROVISION
# per: PROVISION
# cent: PROVISION
# of: PROVISION
# the: PROVISION
# sharehold: PROVISION
# ##ing: ORG
# in: PROVISION
# sk: PROVISION
# e: PROVISION
# &: PROVISION
# c: PROVISION
# jur: PROVISION
# ##ong: PROVISION
# investment: PROVISION
# p: PROVISION
# ##t: PROVISION
# ##e: PROVISION
# ltd: PROVISION
# (: PROVISION
# ": PROVISION
# sk: PROVISION
# ##ec: PROVISION
# ##j: PROVISION
# ##i: PROVISION
# ": PROVISION
# ): PROVISION
# which: PROVISION
# held: PROVISION
# 75: PROVISION
# per: PROVISION
# cent: PROVISION
# of: PROVISION
# the: PROVISION
# sharehold: PROVISION
# ##ing: ORG
# in: PROVISION
# sk: PROVISION
# international: PROVISION
# investment: PROVISION
# singa: PROVISION
# ##pore: PROVISION
# p: PROVISION
# ##t: PROVISION
# ##e: PROVISION
# ltd: PROVISION
# (: PROVISION
# ": PROVISION
# ski: PROVISION
# ##is: PROVISION
# ": PROVISION
# ): PROVISION
# ,: PROVISION
# and: PROVISION
# ski: PROVISION
# ##is: PROVISION
# in: PROVISION
# turn: PROVISION
# held: PROVISION
# 30: PROVISION
# per: PROVISION
# cent: PROVISION
# of: PROVISION
# the: PROVISION
# sharehold: PROVISION
# ##ing: PROVISION
# in: PROVISION
# jac: PROVISION
# .: PROVISION
# u: PROVISION
# ##v: PROVISION
# ##m: PROVISION
# investment: PROVISION
# corporation: PROVISION
# was: PROVISION
# a: PROVISION
# company: PROVISION
# incorporated: PROVISION
# in: PROVISION
# the: PROVISION
# britis: PROVISION
# ##h: PROVISION
# virgin: PROVISION
# island: PROVISION
# ##s: PROVISION
# on: PROVISION
# [SEP]: PROVISION

# %% [markdown]
# # AHHHH

# %%
import os
import json
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForTokenClassification
from sklearn.model_selection import train_test_split
from transformers import DataCollatorForTokenClassification
from transformers import TrainingArguments, Trainer

folder_path = os.path.join("content/jsonl_files")

# Define the full label names based on your data
full_label_list = ["PRECEDENT", "LAWYER", "JUDGE", "RESPONDENT", "GPE",
                   "DATE", "OTHER_PERSON", "PROVISION", "ORG", "PETITIONER",
                   "WITNESS", "COURT", "STATUTE", "CASE_NUMBER"]

# Split the data into train and validation sets
train_files, val_files = train_test_split(os.listdir(folder_path), test_size=0.2, random_state=42)

class CustomDataset(Dataset):
    def __init__(self, file_list, tokenizer, label_list, max_length=512):
        self.tokenizer = tokenizer
        self.label_list = label_list
        self.label_map = {label: i for i, label in enumerate(label_list)}
        self.samples = []
        self.max_length = max_length

        self._load_data(file_list)

    def _load_data(self, file_list):
        for file_name in file_list:
            if file_name.endswith('.jsonl'):
                file_path = os.path.join(folder_path, file_name)
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        text = data['text']
                        labels = data['label']
                        tokenized_inputs = self.tokenizer(
                            text,
                            is_split_into_words=True,
                            padding='max_length',
                            truncation=True,
                            max_length=self.max_length,
                            return_tensors='pt'
                        )
                        labels = self.align_labels(labels, tokenized_inputs.input_ids)
                        self.samples.append({
                            'input_ids': tokenized_inputs.input_ids.squeeze(0),
                            'attention_mask': tokenized_inputs.attention_mask.squeeze(0),
                            'labels': labels
                        })

    def align_labels(self, labels, input_ids):
        max_length = input_ids.size(1)
        aligned_labels = [-100] * max_length  # Initialize with padding token
        
        for start, end, label in labels:
            for i in range(start, min(end, max_length)):
                aligned_labels[i] = self.label_list.index(label)
                
        return torch.tensor(aligned_labels)


    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]
        return sample


# Initialize tokenizer and model
tokenizer = BertTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = BertForTokenClassification.from_pretrained("nlpaueb/legal-bert-base-uncased", num_labels=len(full_label_list))

# Initialize train and validation datasets
train_dataset = CustomDataset(train_files, tokenizer, full_label_list)
eval_dataset = CustomDataset(val_files, tokenizer, full_label_list)
data_collator = DataCollatorForTokenClassification(tokenizer)
# Prepare training arguments and trainer
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    logging_dir='./logs',
)

# Initialize trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator,
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()

# Save the model
model.save_pretrained('./legal_bert_ner_model4')
tokenizer.save_pretrained('./legal_bert_ner_model4')
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at nlpaueb/legal-bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='12' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12/12 00:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>
# ('./legal_bert_ner_model4/tokenizer_config.json',
#  './legal_bert_ner_model4/special_tokens_map.json',
#  './legal_bert_ner_model4/vocab.txt',
#  './legal_bert_ner_model4/added_tokens.json')

# %%
import torch

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Put the model on the device
model.to(device)

# Set the model in evaluation mode
model.eval()

# Iterate over the evaluation dataset and make predictions
predictions = []
for batch in eval_dataset:
    # Move inputs to the appropriate device
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)

    # Disable gradient calculation
    with torch.no_grad():
        # Forward pass, get logits
        outputs = model(input_ids, attention_mask=attention_mask)

    # Get the predicted labels
    predicted_labels = torch.argmax(outputs.logits, dim=-1)
    
    # Append predictions to the list
    predictions.append(predicted_labels.detach().cpu().numpy())

# Convert the list of predictions to a single numpy array
predictions = np.concatenate(predictions)

# Now you have predictions for all samples in the evaluation dataset
print(predictions)

# Define a function to convert integer labels to label names
def convert_labels_to_names(predictions, label_list):
    label_names = []
    for pred in predictions:
        label_names.append([label_list[idx] for idx in pred])
    return label_names

# Convert predicted labels to label names
predicted_label_names = convert_labels_to_names(predictions, label_list)

# Print some examples of predicted labels
for i in range(5):  # Print the first 5 examples
    print("Predicted Labels:", predicted_label_names[i])

u_pred = []
for doc in predicted_label_names:
    for pred in doc:
        if pred not in u_pred:
            u_pred.append(pred)

print(u_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 22
#      19 # Disable gradient calculation
#      20 with torch.no_grad():
#      21     # Forward pass, get logits
# ---> 22     outputs = model(input_ids, attention_mask=attention_mask)
#      24 # Get the predicted labels
#      25 predicted_labels = torch.argmax(outputs.logits, dim=-1)
#
# File /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:1758, in BertForTokenClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1752 r"""
#    1753 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1754     Labels for computing the token classification loss. Indices should be in `[0, ..., config.num_labels - 1]`.
#    1755 """
#    1756 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1758 outputs = self.bert(
#    1759     input_ids,
#    1760     attention_mask=attention_mask,
#    1761     token_type_ids=token_type_ids,
#    1762     position_ids=position_ids,
#    1763     head_mask=head_mask,
#    1764     inputs_embeds=inputs_embeds,
#    1765     output_attentions=output_attentions,
#    1766     output_hidden_states=output_hidden_states,
#    1767     return_dict=return_dict,
#    1768 )
#    1770 sequence_output = outputs[0]
#    1772 sequence_output = self.dropout(sequence_output)
#
# File /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/anaconda3/envs/IS450_NER/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:967, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     964 else:
#     965     raise ValueError("You have to specify either input_ids or inputs_embeds")
# --> 967 batch_size, seq_length = input_shape
#     968 device = input_ids.device if input_ids is not None else inputs_embeds.device
#     970 # past_key_values_length
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
import json

file_path = "admin.jsonl"

# Open the JSON file and read its contents
with open(file_path, "r") as file:
    # Read each line (dictionary) in the file
    for line in file:
        # Parse the JSON dictionary
        data = json.loads(line)
        
        
        # Now 'data' contains the contents of each dictionary
        # You can access the data and perform further processing here
        print(data.keys())
# Out:
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])
# dict_keys(['id', 'text', 'label', 'Comments'])

# %% [markdown]
# # PLEASE

# %%
# model attempt 1
import os
import json
import torch
from torch.utils.data import Dataset
from transformers import BertTokenizer, BertForTokenClassification, TrainingArguments, Trainer
from transformers import DataCollatorForTokenClassification

folder_path = os.path.join("content/jsonl_files")
#tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
# |      >>> model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2")
## |      >>> assistant_model = AutoModelForCausalLM.from_pretrained("distilbert/distilgpt2")
# |      >>> # set pad_token_id to eos_token_id because GPT2 does not have a PAD token
# |      >>> model.generation_config.pad_token_id = model.generation_config.eos_token_id
# |      >>> input_prompt = "It might be possible to"
# |      >>> input_ids = tokenizer(input_prompt, return_tensors="pt").input_ids
# |      >>> # instantiate logits processors
# |      >>> logits_processor = LogitsProcessorList(
# |      ...     [
# |      ...         MinLengthLogitsProcessor(10, eos_token_id=model.generation_config.eos_token_id),
# |      ...     ]
# |      ... )
# |      >>> stopping_criteria = StoppingCriteriaList([MaxLengthCriteria(max_length=20)])
# |      >>> outputs = model.assisted_decoding(
 #|      ...     input_ids,
 #|      ...     assistant_model=assistant_model,
 #|      ...     logits_processor=logits_processor,
 #|      ...     stopping_criteria=stopping_criteria,




# Define the label list based on your data
label_list = ["PRECEDENT", "LAWYER", "JUDGE", "RESPONDENT", "GPE",
              "DATE", "OTHER_PERSON", "PROVISION", "ORG", "PETITIONER",
              "WITNESS", "COURT", "STATUTE", "CASE_NUMBER"]


class CustomDataset(Dataset):
    def __init__(self, folder_path, tokenizer, label_list, max_length=512, split_ratio=0.8, seed=42):
        self.tokenizer = tokenizer
        self.label_list = label_list
        self.label_map = {label: i for i, label in enumerate(label_list)}
        self.samples = []
        self.max_length = max_length
        self.split_ratio = split_ratio
        self.seed = seed

        self._load_data(folder_path)
        self._split_data()

    def _load_data(self, folder_path):
        for file_name in os.listdir(folder_path):
            if file_name.endswith('.jsonl'):
                file_path = os.path.join(folder_path, file_name)
                with open(file_path, 'r') as file:
                    for line in file:
                        data = json.loads(line)
                        text = data['text']
                        labels = data['label']
                        tokenized_inputs = self.tokenizer(
                            text,
                            is_split_into_words=True,
                            padding='max_length',
                            truncation=True,
                            max_length=self.max_length,
                            return_tensors='pt'
                        )
                        labels = self.align_labels(labels, tokenized_inputs.input_ids)
                        self.samples.append({
                            'input_ids': tokenized_inputs.input_ids,
                            'attention_mask': tokenized_inputs.attention_mask,
                            'labels': labels
                        })

    def _split_data(self):
        split_index = int(len(self.samples) * self.split_ratio)
        self.train_samples = self.samples[:split_index]
        self.eval_samples = self.samples[split_index:]

    def align_labels(self, labels, input_ids):
        aligned_labels = []
        label_idx = 0
        for i in range(input_ids.size(1)):
            token = self.tokenizer.convert_ids_to_tokens(input_ids[0, i].item())
            if token.startswith("##"):
                aligned_labels.append(-100)
            else:
                if label_idx < len(labels) and i >= labels[label_idx][0] and i <= labels[label_idx][1]:
                    aligned_labels.append(self.label_map.get(labels[label_idx][2], -100))
                else:
                    aligned_labels.append(-100)
                if label_idx < len(labels) and i == labels[label_idx][1]:
                    label_idx += 1
        return torch.tensor(aligned_labels)

    def __len__(self):
        return len(self.train_samples)

    def __getitem__(self, idx):
        sample = self.train_samples[idx]
        return sample

    def get_eval_dataset(self):
        return self.eval_samples


class CustomDataCollatorForTokenClassification(DataCollatorForTokenClassification):
    def __call__(self, features):
        batch = {}
        batch["input_ids"] = torch.stack([feature["input_ids"].squeeze() for feature in features])
        batch["attention_mask"] = torch.stack([feature["attention_mask"].squeeze() for feature in features])
        batch["labels"] = torch.stack([feature["labels"].squeeze() for feature in features])

        return batch

tokenizer = BertTokenizer.from_pretrained("nlpaueb/legal-bert-base-uncased")
model = BertForTokenClassification.from_pretrained("nlpaueb/legal-bert-base-uncased", num_labels=len(label_list))

data_collator = CustomDataCollatorForTokenClassification(tokenizer)
# Initialize dataset
dataset = CustomDataset(folder_path, tokenizer, label_list)

# Get evaluation dataset
eval_dataset = dataset.get_eval_dataset()

# Prepare training arguments and trainer
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    logging_dir='./logs',
)

# Initialize trainer after defining the model and label_list
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    eval_dataset=eval_dataset,
    data_collator=data_collator,
)

# Train the model
trainer.train()

# Evaluate the model
results = trainer.evaluate()

# Save the model
model.save_pretrained('./legal_bert_ner_model')
tokenizer.save_pretrained('./legal_bert_ner_model')
